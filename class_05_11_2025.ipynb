# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjithtg-omr/AI_ML_RANJITH/blob/Class-05-11-2025/class_05_11_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=34
num2=3
num3=num1+num2
print(num3)
# Out:
# 37

# %%
1#function name
2#inputs/(arguments)
3#output

# %%
def add_Numbers(numb1,numb2):
  result=numb1+numb2
  return (result)
  #return result

# %%
add_Numbers(69,37)
# Out:
# 106

# %%
def display_error():
  print('your username or password is incorrect')

# %%
display_error()
# Out:
# your username or password is incorrect

# %%
def cube_number(number):
  cube=number**3
  return cube

num8=5
num6=cube_number(num8)
print(num6)
# Out:
# 125

# %%
u_name='jishnu'
p_word='admin'

# %%
def login():
  username=input('Enter your username:')
  password=input('Enter your password:')
  if(username==u_name):
    if(password==p_word):
      print(' you logged in successfully ')
    else:
      print(' incorrect credentials-1')
  else:
    print('incorrect credentials-2')

# %%
login()
# Out:
# Enter your username:jishnu
# Enter your password:admin
#  you logged in successfully

# %%
login()
# Out:
# Enter your username:ranjith
# Enter your password:admin
# incorrect credentials-2

# %%
login()
# Out:
# Enter your username:jishnu
# Enter your password:sethu
#  incorrect credentials-1

# %%
def MFA():
  return False
def display_error():
  print("something went wrong")

def login():
  user_name=input("enter username:")
  pass_word=input("enter password:")
  if (user_name==u_name and pass_word==p_word):
    if(MFA()):
      return True
      print("login successful")
    else:
      print('Failed')
      return False
  else:
    return False

# %%
if(login()):
  print("Successfull Login")
else:
  display_error()
# Out:
# enter username:jishnu
# enter password:admin
# Failed
# something went wrong
